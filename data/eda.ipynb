# %%
import pandas as pd

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Users\Public\exo-habitability-ranker\data

# %%
df = pd.read_csv("c:/Users/Public/exo-habitability-ranker/data/ps_2025-06-11.csv")
print(f"Shape: {df.shape}")
df.head()
# Out:
# C:\Users\ual-laptop\AppData\Local\Temp\ipykernel_13824\681210271.py:1: DtypeWarning: Columns (65,187) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("c:/Users/Public/exo-habitability-ranker/data/ps_2025-06-11.csv")
# Shape: (38479, 354)
#          pl_name pl_letter     hostname   hd_name   hip_name         tic_id  \
# 0   Kepler-163 c         c   Kepler-163       NaN        NaN  TIC 271355638
# 1  Kepler-1614 b         b  Kepler-1614       NaN        NaN   TIC 48451562
# 2      TOI-451 d         d      TOI-451       NaN        NaN  TIC 257605131
# 3    Kepler-48 b         b    Kepler-48       NaN        NaN  TIC 171882123
# 4     HD 49674 b         b     HD 49674  HD 49674  HIP 32916   TIC 21267079
#
#                         gaia_id  default_flag  \
# 0  Gaia DR2 2128525769736134016             1
# 1  Gaia DR2 2132314858600815488             0
# 2  Gaia DR2 4844691297067063424             0
# ...

# %%
df.columns.tolist()
# Out:
# ['pl_name',
#  'pl_letter',
#  'hostname',
#  'hd_name',
#  'hip_name',
#  'tic_id',
#  'gaia_id',
#  'default_flag',
#  'pl_refname',
#  'sy_refname',
#  'disc_pubdate',
#  'disc_year',
#  'discoverymethod',
#  'disc_locale',
#  'disc_facility',
#  'disc_instrument',
#  'disc_telescope',
#  'disc_refname',
#  'ra',
#  'rastr',
#  'dec',
#  'decstr',
#  'glon',
#  'glat',
#  'elon',
#  'elat',
#  'pl_orbper',
#  'pl_orbpererr1',
#  'pl_orbpererr2',
#  'pl_orbperlim',
#  'pl_orbperstr',
#  'pl_orblpererr1',
#  'pl_orblper',
#  'pl_orblpererr2',
#  'pl_orblperlim',
#  'pl_orblperstr',
#  'pl_orbsmax',
#  'pl_orbsmaxerr1',
#  'pl_orbsmaxerr2',
#  'pl_orbsmaxlim',
#  'pl_orbsmaxstr',
#  'pl_orbincl',
#  'pl_orbinclerr1',
#  'pl_orbinclerr2',
#  'pl_orbincllim',
#  'pl_orbinclstr',
#  'pl_orbtper',
#  'pl_orbtpererr1',
#  'pl_orbtpererr2',
#  'pl_orbtperlim',
#  'pl_orbtperstr',
#  'pl_orbeccen',
#  'pl_orbeccenerr1',
#  'pl_orbeccenerr2',
#  'pl_orbeccenlim',
#  'pl_orbeccenstr',
# ...

# %%
df[["pl_name", "pl_rade", "pl_eqt", "st_teff", "st_lum"]].isna().sum()
# Out:
# pl_name        0
# pl_rade    11950
# pl_eqt     21681
# st_teff     3217
# st_lum     28985
# dtype: int64

# %%
df[["pl_rade", "pl_eqt", "st_teff", "st_lum"]].describe()
# Out:
#             pl_rade        pl_eqt       st_teff       st_lum
# count  26529.000000  16798.000000  35262.000000  9494.000000
# mean       5.435291    877.301940   5465.705952    -0.147746
# std       72.548527    427.222823    993.231658     0.711595
# min        0.270000     34.000000    415.000000    -4.660000
# 25%        1.550000    567.000000   5103.000000    -0.457090
# 50%        2.290000    795.000000   5614.000000    -0.083790
# 75%        3.230000   1098.000000   5952.000000     0.302042
# max     4282.980000   4050.000000  57000.000000     3.260760

# %%
df[df["pl_name"].str.contains("TRAPPIST|Kepler-22", case=False)]
# Out:
#             pl_name pl_letter    hostname hd_name hip_name         tic_id  \
# 20     Kepler-223 e         e  Kepler-223     NaN      NaN  TIC 273876171
# 114    Kepler-221 c         c  Kepler-221     NaN      NaN  TIC 272601375
# 260    Kepler-220 c         c  Kepler-220     NaN      NaN  TIC 159759306
# 274    Kepler-222 c         c  Kepler-222     NaN      NaN  TIC 158625100
# 280    Kepler-228 d         d  Kepler-228     NaN      NaN   TIC 27772524
# ...             ...       ...         ...     ...      ...            ...
# 38172  Kepler-224 d         d  Kepler-224     NaN      NaN  TIC 159642189
# 38246  Kepler-229 c         c  Kepler-229     NaN      NaN  TIC 399912169
# 38346  Kepler-221 e         e  Kepler-221     NaN      NaN  TIC 272601375
# 38360  Kepler-228 c         c  Kepler-228     NaN      NaN   TIC 27772524
# 38363  Kepler-229 b         b  Kepler-229     NaN      NaN  TIC 399912169
#
#                             gaia_id  default_flag  \
# ...

# %%
df = pd.read_csv("c:/Users/Public/exo-habitability-ranker/ranked_planets.csv")
df.head(20)  # or .style.background_gradient("Greens")
# Out:
#           pl_name    radius    temp  star_temp  star_lum      flux  \
# 0      TOI-2406 b  2.940000  447.00     3100.0   0.53148  1.846369
# 1   Kepler-1638 b  1.600000  304.00     5906.0  -0.11400 -0.109112
# 2     Kepler-69 c  1.710000  299.00     5638.0  -0.09700 -0.101877
# 3     Kepler-69 c  1.790000  325.00     5700.0  -0.02100 -0.021579
# 4     Kepler-22 b  2.380000  262.00     5518.0  -0.10200 -0.111839
# 5   Kepler-1606 b  2.230000  324.00     5461.0  -0.17100 -0.191429
# 6     HD 136352 d  2.562000  431.00     5664.0   0.01620  0.016859
# 7     Kepler-20 d  2.750000  369.00     5455.0  -0.14874 -0.166876
# 8     Kepler-10 c  2.227000  485.00     5627.0   0.00173  0.001824
# 9     Kepler-62 f  1.410000  208.00     4925.0  -0.67800 -0.933195
# 10  Kepler-1544 b  1.790000  269.00     4820.0  -0.60600 -0.870830
# 11      TOI-561 e  2.550000  415.00     5372.0  -0.27327 -0.316137
# 12    Kepler-62 e  1.610000  270.00     4925.0  -0.67800 -0.933195
# ...
